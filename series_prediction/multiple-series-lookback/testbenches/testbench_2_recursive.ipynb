# %%
from config.param import DATA_DIR
from generic_multiple_series_lookback import generic_multiple_series_lookback

input_csv_file = f"{DATA_DIR}/sessions_complete/eeg_subject_4.csv"
csv_sep = ","
sel_features = [
    "alpha1",
    "alpha2",
    "beta1",
    "beta2",
    "delta",
    "gamma1",
    "gamma2",
    "theta"
]
train_split = 0.67
look_back = 512
batch_size = 256
epochs = 10
plot_prefix = "eeg_complete_session"
lstm_units = 128

generic_multiple_series_lookback(
    input_csv_file,
    sel_features,
    train_split=train_split,
    look_back=look_back,
    lstm_units=lstm_units,
    batch_size=batch_size,
    epochs=epochs,
    plot_prefix=plot_prefix,
    force_retrain=True
)
# Out:
# Only 8 of 11 total feature will be used.
# Selected features: ['alpha1', 'alpha2', 'beta1', 'beta2', 'delta', 'gamma1', 'gamma2', 'theta']
# Train input:target shape = (10470, 512, 8):(10470, 8)
# Test input:target shape = (4898, 512, 8):(4898, 8)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 128)               70144
# _________________________________________________________________
# dense (Dense)                (None, 8)                 1032
# =================================================================
# Total params: 71,176
# Trainable params: 71,176
# Non-trainable params: 0
# _________________________________________________________________
# Force retrain set. Use force_retrain=False to keep trained model.
# Training model...
# Epoch 1/10
# 41/41 - 6s - loss: 0.0556
# Epoch 2/10
# 41/41 - 3s - loss: 0.0305
# Epoch 3/10
# 41/41 - 3s - loss: 0.0220
# Epoch 4/10
# 41/41 - 3s - loss: 0.0175
# Epoch 5/10
# 41/41 - 3s - loss: 0.0153
# Epoch 6/10
# 41/41 - 3s - loss: 0.0143
# Epoch 7/10
# 41/41 - 3s - loss: 0.0139
# Epoch 8/10
# 41/41 - 3s - loss: 0.0134
# Epoch 9/10
# 41/41 - 3s - loss: 0.0131
# Epoch 10/10
# 41/41 - 3s - loss: 0.0128
# INFO:tensorflow:Assets written to: models/eeg_complete_session_model\assets
# Train Score alpha1: 33.92973847750144 RMSE
# Test Score alpha1: 25.010549169681212 RMSE
# Train Score alpha2: 28.070905984478493 RMSE
# Test Score alpha2: 21.391795195652406 RMSE
# Train Score beta1: 26.64006724107833 RMSE
# Test Score beta1: 18.645340489577215 RMSE
# Train Score beta2: 22.98154589782228 RMSE
# Test Score beta2: 17.02973242525295 RMSE
# Train Score delta: 38.509803947079696 RMSE
# Test Score delta: 39.95414434982981 RMSE
# Train Score gamma1: 19.209854224926758 RMSE
# Test Score gamma1: 13.300924078294665 RMSE
# Train Score gamma2: 18.534422188001518 RMSE
# Test Score gamma2: 12.459232675113626 RMSE
# Train Score theta: 35.59854411633582 RMSE
# Test Score theta: 30.828525904501113 RMSE
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/eeg_complete_session_model\assets
