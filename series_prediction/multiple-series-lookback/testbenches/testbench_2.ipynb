# %%
from config.param import DATA_DIR
from generic_multiple_series_lookback import generic_multiple_series_lookback

input_csv_file = f"{DATA_DIR}/sessions_complete/eeg_subject_4.csv"
csv_sep = ","
sel_features = [
    "alpha1",
    "alpha2",
    "beta1",
    "beta2",
    "delta",
    "gamma1",
    "gamma2",
    "theta"
]
train_split = 0.67
look_back = 5
batch_size = 8
epochs = 10
plot_prefix = "eeg_complete_session"
lstm_units = 32

generic_multiple_series_lookback(
    input_csv_file,
    sel_features,
    train_split=train_split,
    look_back=look_back,
    lstm_units=lstm_units,
    batch_size=batch_size,
    epochs=epochs,
    plot_prefix=plot_prefix
)
# Out:
# Only 8 of 16392 total feature will be used.
# Selected features: ['alpha1', 'alpha2', 'beta1', 'beta2', 'delta', 'gamma1', 'gamma2', 'theta']
# Train input:target shape = (10977, 5, 8):(10977, 8)
# Test input:target shape = (5405, 5, 8):(5405, 8)
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 32)                5248
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 264
# =================================================================
# Total params: 5,512
# Trainable params: 5,512
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 1373/1373 - 8s - loss: 0.0251
# Epoch 2/10
# 1373/1373 - 6s - loss: 0.0142
# Epoch 3/10
# 1373/1373 - 5s - loss: 0.0131
# Epoch 4/10
# 1373/1373 - 5s - loss: 0.0129
# Epoch 5/10
# 1373/1373 - 6s - loss: 0.0128
# Epoch 6/10
# 1373/1373 - 5s - loss: 0.0127
# Epoch 7/10
# 1373/1373 - 6s - loss: 0.0126
# Epoch 8/10
# 1373/1373 - 5s - loss: 0.0126
# Epoch 9/10
# 1373/1373 - 5s - loss: 0.0126
# Epoch 10/10
# 1373/1373 - 6s - loss: 0.0126
# Train Score alpha1: 34.37404632491935 RMSE
# Test Score alpha1: 23.76318175866293 RMSE
# Train Score alpha2: 28.310082214958626 RMSE
# Test Score alpha2: 20.64193164062566 RMSE
# Train Score beta1: 27.16172726623937 RMSE
# Test Score beta1: 17.823280732682953 RMSE
# Train Score beta2: 23.07026943076503 RMSE
# Test Score beta2: 16.407921686695722 RMSE
# Train Score delta: 36.77541301566229 RMSE
# Test Score delta: 37.189856545602865 RMSE
# Train Score gamma1: 19.643637677397354 RMSE
# Test Score gamma1: 13.332653692924902 RMSE
# Train Score gamma2: 17.602726870531143 RMSE
# Test Score gamma2: 11.262716865252951 RMSE
# Train Score theta: 35.26464978947413 RMSE
# Test Score theta: 30.458726978550764 RMSE
