# %%
from generic_multiple_series_lookback import generic_multiple_series_lookback

input_csv_file = "data/sessions/multi_subject_alfa_1.csv"
csv_sep = ","
sel_features = [
    "Subject1, Alfa1",
    "Subject2, Alfa1",
    "Subject3, Alfa1",
    "Subject4, Alfa1",
    "Subject5, Alfa1",
    "Subject6, Alfa1",
]
train_split = 0.67
look_back = 1
batch_size = 1
epochs = 100
plot_prefix = "eeg_multiple_subjects_"

generic_multiple_series_lookback(
    input_csv_file,
    sel_features,
    csv_sep=",",
    train_split=0.67,
    look_back=1,
    batch_size=1,
    epochs=100,
    verbose=2,
    plot_prefix=plot_prefix
)
# Out:
# Only 6 of 78 total feature will be used.
# Selected features: ['Subject1, Alfa1', 'Subject2, Alfa1', 'Subject3, Alfa1', 'Subject4, Alfa1', 'Subject5, Alfa1', 'Subject6, Alfa1']
# Train input:target shape = (51, 1, 6):(51, 6)
# Test input:target shape = (25, 1, 6):(25, 6)
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_6 (LSTM)                (None, 4)                 176
# _________________________________________________________________
# dense_6 (Dense)              (None, 6)                 30
# =================================================================
# Total params: 206
# Trainable params: 206
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 51/51 - 2s - loss: 0.2116
# Epoch 2/100
# 51/51 - 0s - loss: 0.1587
# Epoch 3/100
# 51/51 - 0s - loss: 0.1170
# Epoch 4/100
# 51/51 - 0s - loss: 0.0853
# Epoch 5/100
# 51/51 - 0s - loss: 0.0633
# Epoch 6/100
# 51/51 - 0s - loss: 0.0508
# Epoch 7/100
# 51/51 - 0s - loss: 0.0447
# Epoch 8/100
# 51/51 - 0s - loss: 0.0419
# Epoch 9/100
# 51/51 - 0s - loss: 0.0405
# Epoch 10/100
# 51/51 - 0s - loss: 0.0400
# Epoch 11/100
# 51/51 - 0s - loss: 0.0395
# Epoch 12/100
# 51/51 - 0s - loss: 0.0394
# Epoch 13/100
# 51/51 - 0s - loss: 0.0392
# Epoch 14/100
# 51/51 - 0s - loss: 0.0391
# Epoch 15/100
# 51/51 - 0s - loss: 0.0389
# Epoch 16/100
# 51/51 - 0s - loss: 0.0388
# Epoch 17/100
# 51/51 - 0s - loss: 0.0388
# Epoch 18/100
# 51/51 - 0s - loss: 0.0387
# Epoch 19/100
# 51/51 - 0s - loss: 0.0386
# Epoch 20/100
# 51/51 - 0s - loss: 0.0385
# Epoch 21/100
# 51/51 - 0s - loss: 0.0385
# Epoch 22/100
# 51/51 - 0s - loss: 0.0384
# Epoch 23/100
# 51/51 - 0s - loss: 0.0383
# Epoch 24/100
# 51/51 - 0s - loss: 0.0382
# Epoch 25/100
# 51/51 - 0s - loss: 0.0382
# Epoch 26/100
# 51/51 - 0s - loss: 0.0381
# Epoch 27/100
# 51/51 - 0s - loss: 0.0381
# Epoch 28/100
# 51/51 - 0s - loss: 0.0380
# Epoch 29/100
# 51/51 - 0s - loss: 0.0379
# Epoch 30/100
# 51/51 - 0s - loss: 0.0378
# Epoch 31/100
# 51/51 - 0s - loss: 0.0378
# Epoch 32/100
# 51/51 - 0s - loss: 0.0377
# Epoch 33/100
# 51/51 - 0s - loss: 0.0378
# Epoch 34/100
# 51/51 - 0s - loss: 0.0377
# Epoch 35/100
# 51/51 - 0s - loss: 0.0376
# Epoch 36/100
# 51/51 - 0s - loss: 0.0375
# Epoch 37/100
# 51/51 - 0s - loss: 0.0375
# Epoch 38/100
# 51/51 - 0s - loss: 0.0373
# Epoch 39/100
# 51/51 - 0s - loss: 0.0374
# Epoch 40/100
# 51/51 - 0s - loss: 0.0374
# Epoch 41/100
# 51/51 - 0s - loss: 0.0372
# Epoch 42/100
# 51/51 - 0s - loss: 0.0373
# Epoch 43/100
# 51/51 - 0s - loss: 0.0371
# Epoch 44/100
# 51/51 - 0s - loss: 0.0372
# Epoch 45/100
# 51/51 - 0s - loss: 0.0371
# Epoch 46/100
# 51/51 - 0s - loss: 0.0370
# Epoch 47/100
# 51/51 - 0s - loss: 0.0368
# Epoch 48/100
# 51/51 - 0s - loss: 0.0368
# Epoch 49/100
# 51/51 - 0s - loss: 0.0368
# Epoch 50/100
# 51/51 - 0s - loss: 0.0366
# Epoch 51/100
# 51/51 - 0s - loss: 0.0367
# Epoch 52/100
# 51/51 - 0s - loss: 0.0365
# Epoch 53/100
# 51/51 - 0s - loss: 0.0364
# Epoch 54/100
# 51/51 - 0s - loss: 0.0365
# Epoch 55/100
# 51/51 - 0s - loss: 0.0364
# Epoch 56/100
# 51/51 - 0s - loss: 0.0362
# Epoch 57/100
# 51/51 - 0s - loss: 0.0362
# Epoch 58/100
# 51/51 - 0s - loss: 0.0364
# Epoch 59/100
# 51/51 - 0s - loss: 0.0361
# Epoch 60/100
# 51/51 - 0s - loss: 0.0360
# Epoch 61/100
# 51/51 - 0s - loss: 0.0361
# Epoch 62/100
# 51/51 - 0s - loss: 0.0359
# Epoch 63/100
# 51/51 - 0s - loss: 0.0359
# Epoch 64/100
# 51/51 - 0s - loss: 0.0358
# Epoch 65/100
# 51/51 - 0s - loss: 0.0357
# Epoch 66/100
# 51/51 - 0s - loss: 0.0357
# Epoch 67/100
# 51/51 - 0s - loss: 0.0356
# Epoch 68/100
# 51/51 - 0s - loss: 0.0355
# Epoch 69/100
# 51/51 - 0s - loss: 0.0355
# Epoch 70/100
# 51/51 - 0s - loss: 0.0354
# Epoch 71/100
# 51/51 - 0s - loss: 0.0355
# Epoch 72/100
# 51/51 - 0s - loss: 0.0353
# Epoch 73/100
# 51/51 - 0s - loss: 0.0352
# Epoch 74/100
# 51/51 - 0s - loss: 0.0353
# Epoch 75/100
# 51/51 - 0s - loss: 0.0353
# Epoch 76/100
# 51/51 - 0s - loss: 0.0351
# Epoch 77/100
# 51/51 - 0s - loss: 0.0351
# Epoch 78/100
# 51/51 - 0s - loss: 0.0351
# Epoch 79/100
# 51/51 - 0s - loss: 0.0352
# Epoch 80/100
# 51/51 - 0s - loss: 0.0350
# Epoch 81/100
# 51/51 - 0s - loss: 0.0350
# Epoch 82/100
# 51/51 - 0s - loss: 0.0350
# Epoch 83/100
# 51/51 - 0s - loss: 0.0350
# Epoch 84/100
# 51/51 - 0s - loss: 0.0348
# Epoch 85/100
# 51/51 - 0s - loss: 0.0347
# Epoch 86/100
# 51/51 - 0s - loss: 0.0350
# Epoch 87/100
# 51/51 - 0s - loss: 0.0347
# Epoch 88/100
# 51/51 - 0s - loss: 0.0347
# Epoch 89/100
# 51/51 - 0s - loss: 0.0347
# Epoch 90/100
# 51/51 - 0s - loss: 0.0347
# Epoch 91/100
# 51/51 - 0s - loss: 0.0347
# Epoch 92/100
# 51/51 - 0s - loss: 0.0346
# Epoch 93/100
# 51/51 - 0s - loss: 0.0345
# Epoch 94/100
# 51/51 - 0s - loss: 0.0344
# Epoch 95/100
# 51/51 - 0s - loss: 0.0345
# Epoch 96/100
# 51/51 - 0s - loss: 0.0344
# Epoch 97/100
# 51/51 - 0s - loss: 0.0345
# Epoch 98/100
# 51/51 - 0s - loss: 0.0345
# Epoch 99/100
# 51/51 - 0s - loss: 0.0344
# Epoch 100/100
# 51/51 - 0s - loss: 0.0344
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000028604B6BAF0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Train Score Subject1, Alfa1: 18.45865212653523 RMSE
# Test Score Subject1, Alfa1: 18.61662414511546 RMSE
# Train Score Subject2, Alfa1: 39.368880263459495 RMSE
# Test Score Subject2, Alfa1: 41.3935076341172 RMSE
# Train Score Subject3, Alfa1: 23.908498339419634 RMSE
# Test Score Subject3, Alfa1: 27.486947535535133 RMSE
# Train Score Subject4, Alfa1: 35.77615059634058 RMSE
# Test Score Subject4, Alfa1: 40.59114941905482 RMSE
# Train Score Subject5, Alfa1: 27.760972249396566 RMSE
# Test Score Subject5, Alfa1: 45.326024529406595 RMSE
# Train Score Subject6, Alfa1: 20.136751372976676 RMSE
# Test Score Subject6, Alfa1: 21.233786088714737 RMSE
